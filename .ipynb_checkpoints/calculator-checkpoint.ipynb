# %% [markdown]
# ![calculator.png](attachment:4a158bf0-73b1-4d06-85c4-da8aad378e40.png)

# %% [markdown]
# # Calculator
#
# ## Simple python - TKINTER built calculator
#
# #### by Joe Eberle started on 05-23-2023 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %%
first_install = False 
if first_install:
    # !pip install schedule
    # !pip install zipp

# %%
import os
import schedule
from datetime import datetime
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import time
import zipfile
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-03-17 at 16:30:01.020600

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'solution_temple'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process solution_temple Step 0 - Initializing and starting Logging Process.

# %%
solution_definition = ''' 

Building a simple calculator in Python is an excellent way to learn the language for several reasons:

Conceptual Understanding: Creating a calculator requires understanding basic arithmetic operations like addition, subtraction, multiplication, and division. This helps beginners grasp fundamental programming concepts such as variables, operators, and data types.

Problem-Solving Skills: While building a calculator, learners encounter various challenges such as handling user input, error handling, and implementing arithmetic operations. Solving these problems enhances problem-solving skills, a crucial aspect of programming.

Immediate Feedback: Python provides immediate feedback, allowing learners to test their code quickly and see the results. This iterative process of writing code, running it, and debugging errors is essential for understanding programming principles.

Real-world Application: Calculators are simple yet practical tools used daily. By building one, learners see the direct application of their programming skills, reinforcing their understanding and motivation to learn more.

Incremental Complexity: Starting with a simple calculator allows learners to gradually increase complexity by adding features like memory functions, scientific calculations, or graphical interfaces. This incremental approach keeps learners engaged and builds confidence as they progress.

Community Support: Since calculators are common beginner projects, there are numerous tutorials, forums, and resources available online. Learners can leverage these resources to seek help, learn new techniques, and interact with the programming community.

Overall, building a simple calculator in Python provides a hands-on learning experience that combines fundamental programming concepts with practical application, making it an effective way to learn the language.

'''

talking_code = True
if talking_code:
    tc.print_say(solution_definition)
# Out:
#
#
# Building a simple calculator in Python is an excellent way to learn the language for several reasons:
#
# Conceptual Understanding: Creating a calculator requires understanding basic arithmetic operations like addition, subtraction, multiplication, and division. This helps beginners grasp fundamental programming concepts such as variables, operators, and data types.
#
# Problem-Solving Skills: While building a calculator, learners encounter various challenges such as handling user input, error handling, and implementing arithmetic operations. Solving these problems enhances problem-solving skills, a crucial aspect of programming.
#
# Immediate Feedback: Python provides immediate feedback, allowing learners to test their code quickly and see the results. This iterative process of writing code, running it, and debugging errors is essential for understanding programming principles.
#
# ...

# %%
print(dir(tc))
# Out:
# ['Initialize_Text_to_Speach', 'Reading_Credits', 'Reading_Intro', 'Reading_Steps', 'Reading_Terms', 'Talking_Code', 'Talking_Voice_Male_Gender', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'column_create_SQL', 'explain_the_project', 'initialize_text_to_speech', 'list_all_xlsx_files', 'out', 'print_say', 'pyttsx3', 'read_credits', 'read_introduction', 'read_process_steps', 'read_terms', 'say', 'set_talking_code_Settings']

# %%
from tkinter import * 

root = Tk()
root.title('Simple Calculator')

e = Entry(root, width=35, borderwidth=5)
e.grid(row=0, column=0, columnspan=3, padx=10, pady=10)
e.insert(0, '' )

global first_number  
global second_number 
global calculator_command  
first_number = 0
second_number = 0
calculator_command = '?'


def button_click(key_number):
    current = e.get()  
    e.delete(0, END)
    e.insert(0, current + str(key_number))
    return 

def button_clear():
    e.delete(0, END)
    return 

def button_add():
    first_number = int(e.get()) 
    e.delete(0, END)
    return 

def button_add():
    global first_number  
    global calculator_command          
    first_number = int(e.get()) 
    calculator_command = '+'
    e.delete(0, END)
    e2.delete(0, END)
    e2.insert(0, f'first#{first_number} Command:{calculator_command} ')    
    return 

def button_multiply():
    global first_number  
    global calculator_command          
    first_number = int(e.get()) 
    calculator_command = '*'
    e.delete(0, END)
    e2.delete(0, END)
    e2.insert(0, f'first{first_number} Command:{calculator_command} ')    
    return 

def button_divide():
    global first_number  
    global calculator_command          
    first_number = int(e.get()) 
    calculator_command = '/'
    e.delete(0, END)
    e2.delete(0, END)
    e2.insert(0, f'first#{first_number} Command:{calculator_command} ')    
    return 


def button_subtract():
    global first_number     
    global calculator_command          
    first_number = int(e.get()) 
    calculator_command = '-'
    e.delete(0, END)
    e2.delete(0, END)
    e2.insert(0, f'first#{first_number} Command:{calculator_command} ') 
    return 

def button_equal():
    global first_number  
    global calculator_command      
    second_number = int(e.get()) 
    if calculator_command == '+':
        result = first_number + second_number   
    if calculator_command == '-':
        result = first_number - second_number 
    if calculator_command == '*':
        result = first_number * second_number   
    if calculator_command == '/':
        result = first_number / second_number    
    e.delete(0, END)         
    e.insert(0, result)          
    e2.delete(0, END)    
    e2.insert(0, f'{first_number} {calculator_command} {second_number} = {result}')  
    e2.insert(0, f'first# + {first_number} Command:{calculator_command} second#{second_number} = {result}')     
    first_number = int(e.get()) 
    return 

button_1 = Button(root, text='1', padx=40, pady=20, command=lambda: button_click(1))
button_2 = Button(root, text='2', padx=40, pady=20, command=lambda: button_click(2))
button_3 = Button(root, text='3', padx=40, pady=20, command=lambda: button_click(3))
button_4 = Button(root, text='4', padx=40, pady=20, command=lambda: button_click(4))
button_5 = Button(root, text='5', padx=40, pady=20, command=lambda: button_click(5))
button_6 = Button(root, text='6', padx=40, pady=20, command=lambda: button_click(6))
button_7 = Button(root, text='7', padx=40, pady=20, command=lambda: button_click(7))
button_8 = Button(root, text='8', padx=40, pady=20, command=lambda: button_click(8))
button_9 = Button(root, text='9', padx=40, pady=20, command=lambda: button_click(9))
button_0 = Button(root, text='0', padx=40, pady=20, command=lambda: button_click(0))

button_multiply = Button(root, text='*', padx=39, pady=20, command=button_multiply)
button_divide = Button(root, text='/', padx=39, pady=20, command=button_divide)
button_subtract = Button(root, text='-', padx=39, pady=20, command=button_subtract)
button_add = Button(root, text='+', padx=39, pady=20, command=button_add)
button_equal = Button(root, text='=', padx=40, pady=20, command=button_equal)
button_clear = Button(root, text='C', padx=40, pady=20, command=button_clear)

button_1.grid(row=3, column=0)
button_2.grid(row=3, column=1)
button_3.grid(row=3, column=2)

button_4.grid(row=2, column=0)
button_5.grid(row=2, column=1)
button_6.grid(row=2, column=2)

button_7.grid(row=1, column=0)
button_8.grid(row=1, column=1)
button_9.grid(row=1, column=2)

button_0.grid(row=4, column=0)
button_clear.grid(row=4, column=1)
 
button_add.grid(row=5, column=0)
button_subtract.grid(row=5, column=1)
button_equal.grid(row=5, column=2)

button_multiply.grid(row=6, column=0)
button_divide.grid(row=6, column=1)


e2 = Entry(root, width=35, borderwidth=5, font='arial 10') 
e2.grid(row=7, column=0, columnspan=3, padx=10, pady=10)
e2.insert(0, 'first#' + str(first_number) + ' Command=' + calculator_command + ' second#' + str(second_number))

root.mainloop()

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-03-15 10:39:07,381 - INFO - START solution_temple =============================================
# 2024-03-15 10:39:07,381 - INFO - START solution_temple Start Time = 2024-03-15 10:39:07
# 2024-03-15 10:39:07,381 - INFO - solution_temple Step 0 - Initialize the configuration file parser
# 2024-03-15 10:39:07,382 - INFO - Process solution_temple Step 0 - Initializing and starting Logging Process.
# 2024-03-15 10:39:07,391 - INFO - PERFORMANCE solution_temple The total process duration was:0.01
# 2024-03-15 10:39:07,391 - INFO - PERFORMANCE solution_temple Stop Time = 2024-03-15 10:39:07
# 2024-03-15 10:39:07,391 - INFO - PERFORMANCE solution_temple Short process duration less than 3 Seconds:0.01
# 2024-03-15 10:39:07,391 - INFO - PERFORMANCE solution_temple Performance optimization is not reccomended
# 2024-03-15 10:39:07,391 - INFO - END solution_temple =============================================

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
